# %%
import numpy as np
from percepton import Perceptron

# %%
X = np.array([
    [2, 3],
    [1, 1],
    [2, 1],
    [-1, -1],
    [-2, -3],
    [-1, -2]
])

y = np.array([1, 1, 1, -1, -1, -1])
model = Perceptron(learn_rate=0.01)
model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 12
#      10 y = np.array([1, 1, 1, -1, -1, -1])
#      11 model = Perceptron(learn_rate=0.01)
# ---> 12 model.fit(X,y)
#
# File ~/Documents/Jesna/Git_ML/ML_algorithms_Scratch/percepton.py:20, in Perceptron.fit(self, X, y, epchos)
#      18 self.errors.append(error)
#      19 if y[j]!=prediction:
# ---> 20     self.weight+=self.learn_rate*y[j]*X[j,:]
#      21     self.bias+=self.learn_rate*y[j]
#
# ValueError: non-broadcastable output operand with shape (2,1) doesn't match the broadcast shape (2,2)
